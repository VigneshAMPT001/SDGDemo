# %%
from sdmetrics.reports.multi_table import QualityReport

report = QualityReport.load('quality_reports/3e71f15d-ae5a-4864-9d4d-5ddb03283702.pkl')

# %%
import plotly.io as pio
pio.renderers.default = 'vscode'
fig = report.get_visualization(
    property_name='Column Shapes',
    table_name='person')
# print(fig.data)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
